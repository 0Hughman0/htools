# %%
import pandas as pd

from bokeh.io import output_notebook, show, push_notebook
from bokeh.models import annotations

from htools.nbinteract import select_peaks, RangeAnalyser
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1680">Loading BokehJS ...</span>
#     </div>

# %%
df = pd.read_csv("testdata.txt", delimiter='\t', usecols=[1, 1, 0], names=('Wavelength', 'Intensity'))

# %% [markdown]
# # Flourometer Spectra

# %%
r = RangeAnalyser(df, 'Intensity')
p = r.build()
print(p)
app = show(p, notebook_url="http://127.0.0.1:8888", notebook_handle=True)
# Out:
# ...
# <script src="http://127.0.0.1:52593/autoload.js?bokeh-autoload-element=1743&bokeh-absolute-url=http://127.0.0.1:52593&resources=none" id="1743"></script>

# %%
an = r.analyses[0]
arrow = annotations.Arrow(x_start=an.maxyx, y_start=an.maxy * 0.9, x_end=an.maxyx, y_end=an.maxyx)
r.fig.add_layout(arrow)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-20-1e0b0025050c> in <module>
#       1 an = r.analyses[0]
#       2 arrow = annotations.Arrow(x_start=an.maxyx, y_start=an.maxy * 0.9, x_end=an.maxyx, y_end=an.maxyx)
# ----> 3 r.fig.add_layout(arrow)
#
# C:\Anaconda3\lib\site-packages\bokeh\models\plots.py in add_layout(self, obj, place)
#     249             obj.plot = self
#     250
# --> 251         self.renderers.append(obj)
#     252
#     253         if place != 'center':
#
# C:\Anaconda3\lib\site-packages\bokeh\core\property\wrappers.py in wrapper(self, *args, **kwargs)
#     123         old = self._saved_copy()
#     124         result = func(self, *args, **kwargs)
# --> 125         self._notify_owners(old)
#     126         return result
#     127     wrapper.__doc__ = "Container method ``%s`` instrumented to notify property owners" % func.__name__
#
# ...
